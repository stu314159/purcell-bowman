# %%
## Import statements

import openmc
import openmc.deplete
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math
from math import pi
import xml.etree.ElementTree as et
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# Analysis Specifications
keffAnalyze = True
depletionAnalyze = True

depletionAnalyzed = False

# %%
# Dimensional Parameters

trisoPkFrac = 0.6 # ratio of triso particle volume to total pebble volume
pebblePkFrac = 0.64 # ratio of pebble volume to core volume

reflctThickness = 66 # cm
coreRadius = 50 # cm
coreHeight = 125 # cm

erchPercent = 19.75 / 100
U_form = 1;
O_form = 2;
rho_fuel = 10.96; # g/cm3

trisoPartThicknesses = [253.5, 97.7, 41.9, 37.5, 45.6]; # um

coolTemp = 450+273.15 #C -> K
coolPres = 8 #MPa

# %%
# Material Definitions

#      Buffer
buffer = openmc.Material(name='Buffer')
buffer.set_density('g/cm3', 1.0)
buffer.add_element('C', 1.0)

#      IPyC
IPyC = openmc.Material(name='IPyC')
IPyC.set_density('g/cm3', 1.9)
IPyC.add_element('C', 1.0)

#      SiC
SiC = openmc.Material(name='SiC')
SiC.set_density('g/cm3', 3.2)
SiC.add_element('C', 0.5)
SiC.add_element('Si', 0.5)

#      OPyC
OPyC = openmc.Material(name='OPyC')
OPyC.set_density('g/cm3', 1.87)
OPyC.add_element('C', 1.0)

# Moderator
graphite = openmc.Material()
graphite.set_density('g/cm3', 1.1995)
graphite.add_element('C', 1.0)

# Coolant
He = openmc.Material(name='He')
He.set_density('g/cm3',coolPres/coolTemp/2.0771)
He.add_element('He',1.0)
He.temperature = coolTemp

# Reflector
Refl = openmc.Material(name='Reflector')
Refl.set_density('g/cm3',1.72)
Refl.add_element('C',1.0)
Refl.add_s_alpha_beta('c_Graphite')

# %%
#TRISO Particle Volume Fraction Calculations
trisoPartRads = trisoPartThicknesses
for i in range(1,5):
    trisoPartRads[i] += trisoPartRads[i-1]
trisoPartVolFracs = trisoPartRads
for i in range(5):
    trisoPartVolFracs[i] = (trisoPartRads[i]/trisoPartRads[4])**3
for i in range(4):
    trisoPartVolFracs[4-i] -= trisoPartVolFracs[3-i]

# %%
#Pebble Volume Fraction Calculations
pebbleRads = [25, 30]
pebbleVolFracs = pebbleRads
for i in range(2):
    pebbleVolFracs[i] = (pebbleRads[i]/pebbleRads[1])**3
pebbleVolFracs[1] -= pebbleVolFracs[0]

# %%
#Fuel Kernel Material definition
fuel = openmc.Material(name="fuel")
fuel.set_density('g/cm3', rho_fuel)
fuel.add_nuclide('U235',erchPercent*U_form/(U_form+O_form))
fuel.add_nuclide('U238',((1-erchPercent)*U_form/(U_form+O_form)))
fuel.add_element('O', O_form/(U_form+O_form))
homogTrisoPart = openmc.Material.mix_materials([fuel, buffer, IPyC, SiC, OPyC], trisoPartVolFracs, 'vo')

# %%
# Homogenize Pebbles
homogTrisoPebCore = openmc.Material.mix_materials([homogTrisoPart,graphite], [trisoPkFrac, 1-trisoPkFrac], 'vo')
homogTrisoPebble = openmc.Material.mix_materials([homogTrisoPebCore, graphite], pebbleVolFracs, 'vo')

# %%
# Core Homogenization and material definition
homogCore = openmc.Material.mix_materials([homogTrisoPebble, He], [pebblePkFrac, 1-pebblePkFrac], 'vo', 'homogCore')
homogCore.add_s_alpha_beta('c_Graphite')
homogCore.volume = math.pi*math.pow(coreRadius, 2)*coreHeight

# %%
# Materials File Creation and Export
materials = openmc.Materials()
materials += [Refl, homogCore]
materials.export_to_xml()

# %%
# Core Model
core = openmc.model.RightCircularCylinder([0,0,0], coreHeight, coreRadius, axis='z', boundary_type = 'transmission')
rflctr = openmc.model.RightCircularCylinder([0,0,-reflctThickness],2*reflctThickness+coreHeight,reflctThickness+coreRadius, axis ='z',boundary_type = 'vacuum') 
rxr = openmc.Cell(fill=homogCore, region=-core)
reflect = openmc.Cell(fill = Refl, region =+core&-rflctr)
surr = openmc.Cell(region =+rflctr)
universe = openmc.Universe(cells=[rxr, reflect, surr])
geometry = openmc.Geometry()
geometry.root_universe = universe
geometry.export_to_xml()

# %%
# Settings
settings = openmc.Settings()
settings.run_mode = 'eigenvalue'
settings.particles = 100000
settings.batches = 75
settings.inactive = 15
settings.temperature={'method':'interpolation','range':(250,2500)}
settings.export_to_xml()

# %%
# Keff Analysis
if keffAnalyze:
    num_threads_des = 136  # set as desired.  Can be useful to ensure you do not take over all the resources for a machine
    num_threads = min(os.cpu_count(),num_threads_des); # prevent asking for more threads than OMP_NUM_THREADS
    openmc.run(output=True)
    sp = openmc.StatePoint('statepoint.45.h5')
    keff = sp.keff
    sp.close()
    keffAnalyze = False
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | e1a8ee7794b441c992426f17fafe216391cbba83
#        Date/Time | 2024-03-31 16:50:59
#   OpenMP Threads | 136
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading Pu236 from /home/m245244/omc_data/lib80x_hdf5/Pu236.h5
#  Reading Pu237 from /home/m245244/omc_data/lib80x_hdf5/Pu237.h5
#  Reading Pu238 from /home/m245244/omc_data/lib80x_hdf5/Pu238.h5
#  Reading Pu239 from /home/m245244/omc_data/lib80x_hdf5/Pu239.h5
#  Reading Pu240 from /home/m245244/omc_data/lib80x_hdf5/Pu240.h5
#  Reading Pu241 from /home/m245244/omc_data/lib80x_hdf5/Pu241.h5
#  Reading Pu242 from /home/m245244/omc_data/lib80x_hdf5/Pu242.h5
#  Reading Pu243 from /home/m245244/omc_data/lib80x_hdf5/Pu243.h5
#  Reading Pu244 from /home/m245244/omc_data/lib80x_hdf5/Pu244.h5
#  Reading Pu245 from /home/m245244/omc_data/lib80x_hdf5/Pu245.h5
#  Reading Pu246 from /home/m245244/omc_data/lib80x_hdf5/Pu246.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Pu236
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.32008
#         2/1    1.15125
#         3/1    1.06104
#         4/1    1.03310
#         5/1    1.01382
#         6/1    1.01447
#         7/1    1.01264
#         8/1    1.00688
#         9/1    1.00438
#        10/1    1.01165
#        11/1    0.98831
#        12/1    0.99088
#        13/1    0.99731
#        14/1    1.00360
#        15/1    1.01007
#        16/1    1.00315
#        17/1    1.00305
#        18/1    0.99541
#        19/1    1.00503
#        20/1    1.00206
#        21/1    0.99644
#        22/1    0.99252
#        23/1    0.97904
#        24/1    0.99550
#       229/1    0.99738    0.99814 +/- 0.00084
#       230/1    0.99278    0.99812 +/- 0.00083
#       231/1    0.99466    0.99810 +/- 0.00083
#       232/1    0.99156    0.99806 +/- 0.00083
#       233/1    1.00461    0.99810 +/- 0.00082
#       234/1    0.99370    0.99807 +/- 0.00082
#       235/1    1.00179    0.99809 +/- 0.00081
#       236/1    0.99279    0.99806 +/- 0.00081
#       237/1    0.98399    0.99799 +/- 0.00081
#       238/1    1.01630    0.99809 +/- 0.00081
#       239/1    1.01871    0.99819 +/- 0.00081
#       240/1    1.00641    0.99824 +/- 0.00081
#       241/1    0.97956    0.99814 +/- 0.00081
#       242/1    0.98560    0.99807 +/- 0.00081
#       243/1    0.98240    0.99799 +/- 0.00081
#       244/1    0.99226    0.99796 +/- 0.00081
#       245/1    0.99477    0.99795 +/- 0.00080
#       246/1    0.99972    0.99796 +/- 0.00080
#       247/1    0.99970    0.99797 +/- 0.00079
#       248/1    1.01477    0.99805 +/- 0.00079
#       249/1    0.99475    0.99803 +/- 0.00079
#       250/1    0.99014    0.99799 +/- 0.00079
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.6593e-01 seconds
#    Reading cross sections          = 4.2396e-01 seconds
#  Total time in simulation          = 1.2854e+00 seconds
#    Time in transport only          = 1.0879e+00 seconds
#    Time in inactive batches        = 2.3819e-01 seconds
#    Time in active batches          = 1.0472e+00 seconds
#    Time synchronizing fission bank = 1.2881e-01 seconds
#      Sampling source sites         = 9.9150e-02 seconds
#      SEND/RECV source sites        = 2.9498e-02 seconds
#    Time accumulating tallies       = 6.9155e-05 seconds
#    Time writing statepoints        = 1.9342e-02 seconds
#  Total time for finalization       = 6.5700e-07 seconds
#  Total time elapsed                = 1.9610e+00 seconds
#  Calculation Rate (inactive)       = 1.04959e+06 particles/second
#  Calculation Rate (active)         = 954932 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.99709 +/- 0.00107
#  k-effective (Track-length)  = 0.99799 +/- 0.00079
#  k-effective (Absorption)    = 0.99905 +/- 0.00155
#  Combined k-effective        = 0.99844 +/- 0.00067
#  Leakage Fraction            = 0.67338 +/- 0.00050

# %%
if depletionAnalyze:
    mdl = openmc.model.Model(geometry, materials, settings)
    op = openmc.deplete.CoupledOperator(mdl,"chain_endfb71_pwr.xml")
    p = 5e6  # watts
    power =         [p,     p,  p, p, p, p,    p, p,    p,  0,  0,  0,    0];
    timesteps =     [.25, .25, .5, 1, 5, 14, 159, 185, 180, 1, 179, 185, 180]  # days
    openmc.deplete.CECMIntegrator(op, timesteps, power, timestep_units='d').integrate()
    results = openmc.deplete.Results("depletion_results.h5")
    depletionAnalyze = False
    depletionAnalyzed = True
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#         Git SHA1 | e1a8ee7794b441c992426f17fafe216391cbba83
#        Date/Time | 2024-03-31 16:51:03
#   OpenMP Threads | 136
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading Pu236 from /home/m245244/omc_data/lib80x_hdf5/Pu236.h5
#  Reading Pu237 from /home/m245244/omc_data/lib80x_hdf5/Pu237.h5
#  Reading Pu238 from /home/m245244/omc_data/lib80x_hdf5/Pu238.h5
#  Reading Pu239 from /home/m245244/omc_data/lib80x_hdf5/Pu239.h5
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the ./model.xml file.
#  Reading Pu240 from /home/m245244/omc_data/lib80x_hdf5/Pu240.h5
#  Reading Pu241 from /home/m245244/omc_data/lib80x_hdf5/Pu241.h5
#  Reading Pu242 from /home/m245244/omc_data/lib80x_hdf5/Pu242.h5
#  Reading Pu243 from /home/m245244/omc_data/lib80x_hdf5/Pu243.h5
#  Reading Pu244 from /home/m245244/omc_data/lib80x_hdf5/Pu244.h5
#  Reading Pu245 from /home/m245244/omc_data/lib80x_hdf5/Pu245.h5
#  Reading Pu246 from /home/m245244/omc_data/lib80x_hdf5/Pu246.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
# ---------------------------------------------------------------------------
# InvalidIDError                            Traceback (most recent call last)
# File ~/anaconda3/envs/openmc-env/lib/python3.11/site-packages/openmc/lib/material.py:279, in _MaterialMapping.__getitem__(self, key)
#     278 try:
# --> 279     _dll.openmc_get_material_index(key, index)
#     280 except (AllocationError, InvalidIDError) as e:
#     281     # __contains__ expects a KeyError to work correctly
#
# File ~/anaconda3/envs/openmc-env/lib/python3.11/site-packages/openmc/lib/error.py:29, in _error_handler(err, func, args)
#      28 if err == errcode('OPENMC_E_INVALID_ID'):
# ---> 29     raise exc.InvalidIDError(msg)
#      30 elif err == errcode('OPENMC_E_GEOMETRY'):
#
# InvalidIDError: No material exists with ID=12.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 8
#       6 timesteps =     [.25, .25, .5, 1, 5, 14, 159, 185, 180, 1, 179, 185, 180]  # days
#       7 openmc.deplete.pool.USE_MULTIPROCESSING = False
# ----> 8 openmc.deplete.CECMIntegrator(op, timesteps, power, timestep_units='d').integrate()
#       9 results = openmc.deplete.Results("depletion_results.h5")
#      10 depletionAnalyze = False
#
# File ~/anaconda3/envs/openmc-env/lib/python3.11/site-packages/openmc/deplete/abc.py:781, in Integrator.integrate(self, final_step, output)
#     766 """Perform the entire depletion process across all steps
#     767
#     768 Parameters
#    (...)
#     778     .. versionadded:: 0.13.1
#     779 """
#     780 with change_directory(self.operator.output_dir):
# --> 781     n = self.operator.initial_condition()
#     782     t, self._i_res = self._get_start_data()
#     784     for i, (dt, source_rate) in enumerate(self):
#
# File ~/anaconda3/envs/openmc-env/lib/python3.11/site-packages/openmc/deplete/coupled_operator.py:388, in CoupledOperator.initial_condition(self)
#     385     openmc.lib.init(intracomm=comm)
#     387 # Generate tallies in memory
# --> 388 materials = [openmc.lib.materials[int(i)] for i in self.burnable_mats]
#     390 return super().initial_condition(materials)
#
# File ~/anaconda3/envs/openmc-env/lib/python3.11/site-packages/openmc/deplete/coupled_operator.py:388, in <listcomp>(.0)
#     385     openmc.lib.init(intracomm=comm)
#     387 # Generate tallies in memory
# --> 388 materials = [openmc.lib.materials[int(i)] for i in self.burnable_mats]
#     390 return super().initial_condition(materials)
#
# File ~/anaconda3/envs/openmc-env/lib/python3.11/site-packages/openmc/lib/material.py:282, in _MaterialMapping.__getitem__(self, key)
#     279     _dll.openmc_get_material_index(key, index)
#     280 except (AllocationError, InvalidIDError) as e:
#     281     # __contains__ expects a KeyError to work correctly
# --> 282     raise KeyError(str(e))
#     283 return Material(index=index.value)
#
# KeyError: 'No material exists with ID=12.'

# %%
if depletionAnalyzed:
    time, KEFF= results.get_keff()
    time = time / (60*60*24*365.25);
    keff_u = []
    keff = []
    for k in KEFF:
        keff_u.append(k[1])
        keff.append(k[0])

# %%
if depletionAnalyzed:
    plt.errorbar(np.array(time), np.array(keff), np.array(keff_u))

# %%
# get depletion results to manipulate
r = openmc.deplete.Results('depletion_results.h5')
bi = len(timesteps)
burned_mats = r.export_to_materials(burnup_index=bi)
xmlName = 'BurnedMaterials'+str(bi)+'.xml'
burned_mats.export_to_xml(xmlName)
mat_tree = et.parse(xmlName)
root = mat_tree.getroot()
i=0
for child in root:
    if child.attrib['name']=='homogCore':
        homogCore = root[i]
        break
    i+=1
homogCore.set('id',24)
print(homogCore.items())
type(homogCore)
burned_homogCore = openmc.Material.from_xml_element(homogCore)
burned_homogCore_mass = burned_homogCore.get_mass()
listnuc = burned_homogCore.get_nuclides() # list of nuclides present in burned fuel
import re
Puiso = []
for nuclide in listnuc:
    if re.search('Pu.+', nuclide):
        Puiso.append(nuclide)
pu_mass =0.
for nuclide in Puiso:
    pu_mass+=burned_homogCore.get_mass(nuclide=nuclide)
pu_mass_fraction = pu_mass/burned_homogCore_mass
SepPu = openmc.Material(name='PuProduct')
SepPu.set_density('g/cc',19.84) # density used for all metallic Plutonium in PNNL Compendium
print(Puiso)
i = len(Puiso)
n = 0
BurnPuAo = []
while (n < i):
    BurnPu = burned_homogCore.get_nuclide_atom_densities(Puiso[n])
    BurnPuAo.append(BurnPu)
    SepPu.add_nuclide(Puiso[n],BurnPu[Puiso[n]])
    n+=1

# %%
def build_model(radius, fuel):
    
    
    materials = openmc.Materials([fuel])
    
    # create sphere with radius parameter
    sphere_radius = openmc.Sphere(x0=0,y0=0,z0=0,r=radius, boundary_type='vacuum', name='BCM')
    
    # create core cell
    core_cell = openmc.Cell(name='Bare Critical Sphere')
    core_cell.fill = fuel
    core_cell.region = -sphere_radius
    
    # create universe geometry
    root_universe = openmc.Universe(name='root universe')
    root_universe.add_cells([core_cell])
    
    geometry = openmc.Geometry(root_universe)
    # define criticality settings
    settings = openmc.Settings()
    settings.run_mode = 'eigenvalue' # keff calculation
    settings.particles = 5000 # particles per batch (mo betta)
    settings.batches = 250 # number of batches
    settings.inactive = 50 # inactive batches
    
    settings.output = {'tallies': False}
    
    bcmModel = openmc.model.Model(geometry,materials,settings)
    
    return bcmModel

# %%
crit_r, guesses, keffs = openmc.search_for_keff(build_model, bracket=[1,50],model_args={'fuel':SepPu},
                                                tol=1e-4, print_iterations=True,
                                               run_args={'output':False})
# print results and collect data
print('Burned Plutonium Critical Mass')
print('The bare critical sphere radius is %7.4f cm.' % crit_r)
crit_v = 4/3*pi*crit_r**3 # volume of critical sphere (cc)

BCM = crit_v * 19.84 /1000 # mass of critical radius (kg)
print('The bare critical mass is %7.3f kg.' % BCM)

BCMs = np.array(BCM)
print(BCMs,'\n')

# %%
netWeight = BCM/burned_homogCore_mass
print(netWeight)
