# %%
import openmc
import openmc.deplete
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi
import xml.etree.ElementTree as et
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
trisoPkFrac = 0.3
pebblePkFrac = 0.64

reflctThickness = 100;

erchPercent = range(5,21)
U_form = 1;
O_form = 2;
rho_fuel = 10.96; # g/cm3

trisoPartThicknesses = [253.5, 97.7, 41.9, 37.5, 45.6]; #um

coolTemp = 450+273.15 #C -> K
coolPres = 8 #MPa

# %%
#      Buffer
buffer = openmc.Material(name='Buffer')
buffer.set_density('g/cm3', 1.0)
buffer.add_element('C', 1.0)
#buffer.add_s_alpha_beta('c_Graphite')

#      IPyC
IPyC = openmc.Material(name='IPyC')
IPyC.set_density('g/cm3', 1.9)
IPyC.add_element('C', 1.0)
#IPyC.add_s_alpha_beta('c_Graphite')

#      SiC
SiC = openmc.Material(name='SiC')
SiC.set_density('g/cm3', 3.2)
SiC.add_element('C', 0.5)
SiC.add_element('Si', 0.5)

#      OPyC
OPyC = openmc.Material(name='OPyC')
OPyC.set_density('g/cm3', 1.87)
OPyC.add_element('C', 1.0)
#OPyC.add_s_alpha_beta('c_Graphite')

# Moderator
graphite = openmc.Material()
graphite.set_density('g/cm3', 1.1995)
graphite.add_element('C', 1.0)
#graphite.add_s_alpha_beta('c_Graphite')

# Coolant
He = openmc.Material(name='He')
He.set_density('g/cm3',coolPres/coolTemp/2.0771)
He.add_element('He',1.0)
He.temperature = coolTemp

# Reflector
Refl = openmc.Material(name='Reflector')
Refl.set_density('g/cm3',1.72)
Refl.add_element('C',1.0)
Refl.add_s_alpha_beta('c_Graphite')

# %%
#B5
trisoPartRads = trisoPartThicknesses
for i in range(1,5):
    trisoPartRads[i] += trisoPartRads[i-1]
trisoPartVolFracs = trisoPartRads
for i in range(5):
    trisoPartVolFracs[i] = (trisoPartRads[i]/trisoPartRads[4])**3
for i in range(4):
    trisoPartVolFracs[4-i] -= trisoPartVolFracs[3-i]

# %%
#B6
pebbleRads = [25, 30]
pebbleVolFracs = pebbleRads
for i in range(2):
    pebbleVolFracs[i] = (pebbleRads[i]/pebbleRads[1])**3
pebbleVolFracs[1] -= pebbleVolFracs[0]

# %%
trisoPkFrac = range(30,60,2)
erchPercent = .1975

# %%
#      Fuel Kernel
fuel = openmc.Material(name="fuel")
fuel.set_density('g/cm3', rho_fuel)
fuel.add_nuclide('U235',erchPercent*U_form/(U_form+O_form))
fuel.add_nuclide('U238',((1-erchPercent)*U_form/(U_form+O_form)))
fuel.add_element('O', O_form/(U_form+O_form))
homogTrisoPart = openmc.Material.mix_materials([fuel, buffer, IPyC, SiC, OPyC], trisoPartVolFracs, 'vo')

# %%
#Enrichment Optimization
k_eff_tPkFrac = []
kitPF = []
for eki in trisoPkFrac:
    #B4
    homogTrisoPebCore = openmc.Material.mix_materials([homogTrisoPart,graphite], [eki/100, 1-eki/100], 'vo');
    homogTrisoPebble = openmc.Material.mix_materials([homogTrisoPebCore, graphite], pebbleVolFracs, 'vo');


    #B7
    homogCore = openmc.Material.mix_materials([homogTrisoPebble, He], [pebblePkFrac, 1-pebblePkFrac], 'vo')
    homogCore.add_s_alpha_beta('c_Graphite')
    materials = openmc.Materials()
    materials += [Refl, homogCore]
    materials.export_to_xml()
    
        #B8
    core = openmc.model.RightCircularCylinder([0,0,0], 125, 50, axis='z', boundary_type = 'transmission')
    rflctr = openmc.model.RightCircularCylinder([0,0,-reflctThickness],2*reflctThickness+125,reflctThickness+50, axis ='z',boundary_type = 'vacuum') 
    rxr = openmc.Cell(fill=homogCore, region=-core)
    reflect = openmc.Cell(fill = Refl, region =+core&-rflctr)
    surr = openmc.Cell(region =+rflctr)
    universe = openmc.Universe(cells=[rxr, reflect, surr])
    geometry = openmc.Geometry()
    geometry.root_universe = universe
    geometry.export_to_xml()
    settings = openmc.Settings()
    settings.run_mode = 'eigenvalue'
    settings.particles = 25000
    settings.batches = 45
    settings.inactive = 15
    settings.temperature={'method':'interpolation','range':(250,2500)}
    settings.export_to_xml()

    

    #B9
    num_threads_des = 136  # set as desired.  Can be useful to ensure you do not take over all the resources for a machine
    num_threads = min(os.cpu_count(),num_threads_des); # prevent asking for more threads than OMP_NUM_THREADS
    
    openmc.run(threads = num_threads, output=True)
    sp = openmc.StatePoint('statepoint.45.h5')
    keff = sp.keff
    k_eff_tPkFrac.append(keff.n)
    kitPF.append(keff.s)
    sp.close()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:26:31
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.09427
#         2/1    1.05976
#         3/1    1.05466
#         4/1    1.05493
#         5/1    1.05817
#         6/1    1.06258
#         7/1    1.06372
#         8/1    1.05824
#         9/1    1.06871
#        10/1    1.05504
#        11/1    1.05914
#        12/1    1.04993
#        13/1    1.07215
#        14/1    1.07021
#        15/1    1.05698
#        16/1    1.05425
#        17/1    1.05445    1.05435 +/- 0.00010
#        18/1    1.05552    1.05474 +/- 0.00039
#        19/1    1.07097    1.05880 +/- 0.00407
#        20/1    1.05451    1.05794 +/- 0.00326
#        21/1    1.05218    1.05698 +/- 0.00283
#        22/1    1.06488    1.05811 +/- 0.00265
#        23/1    1.03650    1.05541 +/- 0.00354
#        24/1    1.04515    1.05427 +/- 0.00333
#        25/1    1.05629    1.05447 +/- 0.00298
#        26/1    1.05208    1.05425 +/- 0.00271
#        27/1    1.05029    1.05392 +/- 0.00249
#        28/1    1.04665    1.05336 +/- 0.00236
#        29/1    1.05162    1.05324 +/- 0.00219
#        30/1    1.05052    1.05306 +/- 0.00204
#        31/1    1.05250    1.05302 +/- 0.00191
#        32/1    1.05482    1.05313 +/- 0.00180
#        33/1    1.07174    1.05416 +/- 0.00199
#        34/1    1.06174    1.05456 +/- 0.00192
#        35/1    1.05261    1.05446 +/- 0.00183
#        36/1    1.07672    1.05552 +/- 0.00203
#        37/1    1.04480    1.05504 +/- 0.00200
#        38/1    1.05981    1.05524 +/- 0.00192
#        39/1    1.05248    1.05513 +/- 0.00184
#        40/1    1.07064    1.05575 +/- 0.00187
#        41/1    1.04352    1.05528 +/- 0.00186
#        42/1    1.06079    1.05548 +/- 0.00180
#        43/1    1.08718    1.05661 +/- 0.00207
#        44/1    1.08255    1.05751 +/- 0.00219
#        45/1    1.06347    1.05771 +/- 0.00213
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8737e+00 seconds
#    Reading cross sections          = 3.8447e+00 seconds
#  Total time in simulation          = 4.3686e+00 seconds
#    Time in transport only          = 4.1592e+00 seconds
#    Time in inactive batches        = 1.4795e+00 seconds
#    Time in active batches          = 2.8891e+00 seconds
#    Time synchronizing fission bank = 1.2263e-01 seconds
#      Sampling source sites         = 1.0437e-01 seconds
#      SEND/RECV source sites        = 1.7924e-02 seconds
#    Time accumulating tallies       = 5.9204e-05 seconds
#    Time writing statepoints        = 1.0642e-02 seconds
#  Total time for finalization       = 7.8100e-07 seconds
#  Total time elapsed                = 8.2837e+00 seconds
#  Calculation Rate (inactive)       = 253469 particles/second
#  Calculation Rate (active)         = 259592 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.05771 +/- 0.00195
#  k-effective (Track-length)  = 1.05771 +/- 0.00213
#  k-effective (Absorption)    = 1.06116 +/- 0.00118
#  Combined k-effective        = 1.06118 +/- 0.00125
#  Leakage Fraction            = 0.14620 +/- 0.00040
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:26:40
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.08407
#         2/1    1.06557
#         3/1    1.05961
#         4/1    1.04550
#         5/1    1.06161
#         6/1    1.04908
#         7/1    1.04309
#         8/1    1.08445
#         9/1    1.04815
#        10/1    1.05421
#        11/1    1.04242
#        12/1    1.06134
#        13/1    1.06762
#        14/1    1.06694
#        15/1    1.06700
#        16/1    1.07032
#        17/1    1.05292    1.06162 +/- 0.00870
#        18/1    1.07204    1.06509 +/- 0.00611
#        19/1    1.06720    1.06562 +/- 0.00435
#        20/1    1.06881    1.06626 +/- 0.00343
#        21/1    1.07875    1.06834 +/- 0.00349
#        22/1    1.06067    1.06724 +/- 0.00315
#        23/1    1.07435    1.06813 +/- 0.00287
#        24/1    1.06826    1.06815 +/- 0.00253
#        25/1    1.05535    1.06687 +/- 0.00260
#        26/1    1.07117    1.06726 +/- 0.00238
#        27/1    1.07161    1.06762 +/- 0.00220
#        28/1    1.04242    1.06568 +/- 0.00281
#        29/1    1.03934    1.06380 +/- 0.00321
#        30/1    1.05669    1.06333 +/- 0.00302
#        31/1    1.06604    1.06350 +/- 0.00283
#        32/1    1.08354    1.06468 +/- 0.00291
#        33/1    1.06209    1.06453 +/- 0.00275
#        34/1    1.03523    1.06299 +/- 0.00302
#        35/1    1.05704    1.06269 +/- 0.00288
#        36/1    1.04729    1.06196 +/- 0.00284
#        37/1    1.07393    1.06250 +/- 0.00276
#        38/1    1.07606    1.06309 +/- 0.00270
#        39/1    1.05622    1.06281 +/- 0.00260
#        40/1    1.07110    1.06314 +/- 0.00252
#        41/1    1.04892    1.06259 +/- 0.00248
#        42/1    1.06546    1.06270 +/- 0.00239
#        43/1    1.06295    1.06271 +/- 0.00230
#        44/1    1.05150    1.06232 +/- 0.00226
#        45/1    1.06415    1.06238 +/- 0.00218
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8650e+00 seconds
#    Reading cross sections          = 3.8410e+00 seconds
#  Total time in simulation          = 4.3237e+00 seconds
#    Time in transport only          = 4.1404e+00 seconds
#    Time in inactive batches        = 1.4450e+00 seconds
#    Time in active batches          = 2.8787e+00 seconds
#    Time synchronizing fission bank = 1.0738e-01 seconds
#      Sampling source sites         = 8.8180e-02 seconds
#      SEND/RECV source sites        = 1.8910e-02 seconds
#    Time accumulating tallies       = 3.5093e-05 seconds
#    Time writing statepoints        = 1.5855e-02 seconds
#  Total time for finalization       = 1.0050e-06 seconds
#  Total time elapsed                = 8.2307e+00 seconds
#  Calculation Rate (inactive)       = 259524 particles/second
#  Calculation Rate (active)         = 260534 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06197 +/- 0.00221
#  k-effective (Track-length)  = 1.06238 +/- 0.00218
#  k-effective (Absorption)    = 1.06209 +/- 0.00112
#  Combined k-effective        = 1.06225 +/- 0.00114
#  Leakage Fraction            = 0.14438 +/- 0.00046
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13
h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8412e+00 seconds
#    Reading cross sections          = 3.8127e+00 seconds
#  Total time in simulation          = 4.2492e+00 seconds
#    Time in transport only          = 4.0630e+00 seconds
#    Time in inactive batches        = 1.4128e+00 seconds
#    Time in active batches          = 2.8364e+00 seconds
#    Time synchronizing fission bank = 1.1720e-01 seconds
#      Sampling source sites         = 9.5568e-02 seconds
#      SEND/RECV source sites        = 2.1282e-02 seconds
#    Time accumulating tallies       = 4.5987e-05 seconds
#    Time writing statepoints        = 9.4444e-03 seconds
#  Total time for finalization       = 1.0430e-06 seconds
#  Total time elapsed                = 8.1316e+00 seconds
#  Calculation Rate (inactive)       = 265425 particles/second
#  Calculation Rate (active)         = 264418 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06344 +/- 0.00197
#  k-effective (Track-length)  = 1.06397 +/- 0.00207
#  k-effective (Absorption)    = 1.06126 +/- 0.00107
#  Combined k-effective        = 1.06191 +/- 0.00100
#  Leakage Fraction            = 0.14343 +/- 0.00041
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:26:57
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.07004
#         2/1    1.05017
#         3/1    1.04397
#         4/1    1.07403
#         5/1    1.06611
#         6/1    1.06695
#         7/1    1.06596
#         8/1    1.06534
#         9/1    1.05635
#        10/1    1.06610
#        11/1    1.07182
#        12/1    1.05850
#        13/1    1.06795
#        14/1    1.05187
#        15/1    1.06371
#        16/1    1.06224
#        17/1    1.06002    1.06113 +/- 0.00111
#        18/1    1.06531    1.06252 +/- 0.00153
#        19/1    1.07080    1.06459 +/- 0.00234
#        20/1    1.05731    1.06314 +/- 0.00232
#        21/1    1.05491    1.06177 +/- 0.00234
#        22/1    1.07934    1.06428 +/- 0.00320
#        23/1    1.06576    1.06446 +/- 0.00277
#        24/1    1.06901    1.06497 +/- 0.00250
#        25/1    1.04352    1.06282 +/- 0.00310
#        26/1    1.07445    1.06388 +/- 0.00299
#        27/1    1.06971    1.06436 +/- 0.00278
#        28/1    1.04168    1.06262 +/- 0.00309
#        29/1    1.08254    1.06404 +/- 0.00320
#        30/1    1.07283    1.06463 +/- 0.00303
#        31/1    1.05166    1.06382 +/- 0.00295
#        32/1    1.07426    1.06443 +/- 0.00284
#        33/1    1.08216    1.06542 +/- 0.00285
#        34/1    1.06009    1.06514 +/- 0.00271
#        35/1    1.07208    1.06548 +/- 0.00260
#        36/1    1.06261    1.06535 +/- 0.00247
#        37/1    1.05581    1.06491 +/- 0.00240
#        38/1    1.08622    1.06584 +/- 0.00247
#        39/1    1.06115    1.06564 +/- 0.00237
#        40/1    1.04852    1.06496 +/- 0.00238
#        41/1    1.08007    1.06554 +/- 0.00236
#        42/1    1.04932    1.06494 +/- 0.00235
#        43/1    1.05134    1.06445 +/- 0.00231
#        44/1    1.06561    1.06449 +/- 0.00223
#        45/1    1.08429    1.06515 +/- 0.00226
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.7977e+00 seconds
#    Reading cross sections          = 3.7718e+00 seconds
#  Total time in simulation          = 4.3306e+00 seconds
#    Time in transport only          = 4.1215e+00 seconds
#    Time in inactive batches        = 1.4378e+00 seconds
#    Time in active batches          = 2.8928e+00 seconds
#    Time synchronizing fission bank = 1.1720e-01 seconds
#      Sampling source sites         = 9.4065e-02 seconds
#      SEND/RECV source sites        = 2.2835e-02 seconds
#    Time accumulating tallies       = 3.8800e-05 seconds
#    Time writing statepoints        = 1.7940e-02 seconds
#  Total time for finalization       = 1.0680e-06 seconds
#  Total time elapsed                = 8.1688e+00 seconds
#  Calculation Rate (inactive)       = 260815 particles/second
#  Calculation Rate (active)         = 259263 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06436 +/- 0.00200
#  k-effective (Track-length)  = 1.06515 +/- 0.00226
#  k-effective (Absorption)    = 1.06483 +/- 0.00116
#  Combined k-effective        = 1.06446 +/- 0.00120
#  Leakage Fraction            = 0.14185 +/- 0.00046
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:27:05
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.07981
#         2/1    1.06230
#         3/1    1.07358
#         4/1    1.04109
#         5/1    1.05311
#         6/1    1.07464
#         7/1    1.05881
#         8/1    1.08193
#         9/1    1.05793
#        10/1    1.05015
#        11/1    1.06328
#        12/1    1.07185
#        13/1    1.06343
#        14/1    1.05177
#        15/1    1.06888
#        16/1    1.08131
#        17/1    1.07162    1.07647 +/- 0.00484
#        18/1    1.09066    1.08120 +/- 0.00549
#        19/1    1.05665    1.07506 +/- 0.00726
#        20/1    1.06638    1.07332 +/- 0.00589
#        21/1    1.06309    1.07162 +/- 0.00510
#        22/1    1.07227    1.07171 +/- 0.00431
#        23/1    1.06267    1.07058 +/- 0.00390
#        24/1    1.05483    1.06883 +/- 0.00386
#        25/1    1.07332    1.06928 +/- 0.00348
#        26/1    1.07051    1.06939 +/- 0.00315
#        27/1    1.06538    1.06906 +/- 0.00290
#        28/1    1.06823    1.06899 +/- 0.00266
#        29/1    1.06192    1.06849 +/- 0.00252
#        30/1    1.07417    1.06887 +/- 0.00237
#        31/1    1.06045    1.06834 +/- 0.00228
#        32/1    1.05889    1.06779 +/- 0.00222
#        33/1    1.06460    1.06761 +/- 0.00210
#        34/1    1.04994    1.06668 +/- 0.00219
#        35/1    1.06135    1.06641 +/- 0.00209
#        36/1    1.04752    1.06551 +/- 0.00219
#        37/1    1.05924    1.06523 +/- 0.00210
#        38/1    1.06775    1.06534 +/- 0.00201
#        39/1    1.05444    1.06488 +/- 0.00198
#        40/1    1.06558    1.06491 +/- 0.00190
#        41/1    1.07074    1.06513 +/- 0.00184
#        42/1    1.05546    1.06478 +/- 0.00181
#        43/1    1.06212    1.06468 +/- 0.00174
#        44/1    1.06313    1.06463 +/- 0.00168
#        45/1    1.06133    1.06452 +/- 0.00163
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8780e+00 seconds
#    Reading cross sections          = 3.8498e+00 seconds
#  Total time in simulation          = 4.3085e+00 seconds
#    Time in transport only          = 4.1338e+00 seconds
#    Time in inactive batches        = 1.4468e+00 seconds
#    Time in active batches          = 2.8617e+00 seconds
#    Time synchronizing fission bank = 1.1014e-01 seconds
#      Sampling source sites         = 8.5490e-02 seconds
#      SEND/RECV source sites        = 2.4358e-02 seconds
#    Time accumulating tallies       = 3.7104e-05 seconds
#    Time writing statepoints        = 8.7695e-03 seconds
#  Total time for finalization       = 8.8500e-07 seconds
#  Total time elapsed                = 8.2275e+00 seconds
#  Calculation Rate (inactive)       = 259185 particles/second
#  Calculation Rate (active)         = 262084 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06335 +/- 0.00165
#  k-effective (Track-length)  = 1.06452 +/- 0.00163
#  k-effective (Absorption)    = 1.06263 +/- 0.00102
#  Combined k-effective        = 1.06270 +/- 0.00093
#  Leakage Fraction            = 0.14104 +/- 0.00038
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13
h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8013e+00 seconds
#    Reading cross sections          = 3.7737e+00 seconds
#  Total time in simulation          = 4.2443e+00 seconds
#    Time in transport only          = 4.0573e+00 seconds
#    Time in inactive batches        = 1.4295e+00 seconds
#    Time in active batches          = 2.8148e+00 seconds
#    Time synchronizing fission bank = 1.1312e-01 seconds
#      Sampling source sites         = 9.2620e-02 seconds
#      SEND/RECV source sites        = 2.0190e-02 seconds
#    Time accumulating tallies       = 3.8215e-05 seconds
#    Time writing statepoints        = 8.3468e-03 seconds
#  Total time for finalization       = 8.9600e-07 seconds
#  Total time elapsed                = 8.0908e+00 seconds
#  Calculation Rate (inactive)       = 262332 particles/second
#  Calculation Rate (active)         = 266446 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06519 +/- 0.00205
#  k-effective (Track-length)  = 1.06425 +/- 0.00212
#  k-effective (Absorption)    = 1.06453 +/- 0.00134
#  Combined k-effective        = 1.06471 +/- 0.00140
#  Leakage Fraction            = 0.14097 +/- 0.00030
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:27:22
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.08431
#         2/1    1.05973
#         3/1    1.05952
#         4/1    1.05542
#         5/1    1.07286
#         6/1    1.06120
#         7/1    1.07490
#         8/1    1.06592
#         9/1    1.05993
#        10/1    1.06077
#        11/1    1.06868
#        12/1    1.05584
#        13/1    1.06474
#        14/1    1.08064
#        15/1    1.07546
#        16/1    1.06877
#        17/1    1.08785    1.07831 +/- 0.00954
#        18/1    1.05367    1.07010 +/- 0.00989
#        19/1    1.06785    1.06954 +/- 0.00701
#        20/1    1.06243    1.06812 +/- 0.00562
#        21/1    1.07521    1.06930 +/- 0.00474
#        22/1    1.06059    1.06805 +/- 0.00419
#        23/1    1.06287    1.06741 +/- 0.00369
#        24/1    1.05798    1.06636 +/- 0.00342
#        25/1    1.05686    1.06541 +/- 0.00320
#        26/1    1.06818    1.06566 +/- 0.00291
#        27/1    1.06879    1.06592 +/- 0.00266
#        28/1    1.06384    1.06576 +/- 0.00246
#        29/1    1.05532    1.06502 +/- 0.00239
#        30/1    1.08048    1.06605 +/- 0.00246
#        31/1    1.04591    1.06479 +/- 0.00262
#        32/1    1.07199    1.06521 +/- 0.00250
#        33/1    1.06867    1.06540 +/- 0.00236
#        34/1    1.06098    1.06517 +/- 0.00225
#        35/1    1.05958    1.06489 +/- 0.00215
#        36/1    1.06142    1.06473 +/- 0.00205
#        37/1    1.07940    1.06539 +/- 0.00207
#        38/1    1.07573    1.06584 +/- 0.00202
#        39/1    1.06589    1.06585 +/- 0.00194
#        40/1    1.06543    1.06583 +/- 0.00186
#        41/1    1.06695    1.06587 +/- 0.00179
#        42/1    1.06494    1.06584 +/- 0.00172
#        43/1    1.07217    1.06606 +/- 0.00167
#        44/1    1.07120    1.06624 +/- 0.00162
#        45/1    1.08247    1.06678 +/- 0.00166
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8505e+00 seconds
#    Reading cross sections          = 3.8174e+00 seconds
#  Total time in simulation          = 4.2978e+00 seconds
#    Time in transport only          = 4.0971e+00 seconds
#    Time in inactive batches        = 1.4437e+00 seconds
#    Time in active batches          = 2.8540e+00 seconds
#    Time synchronizing fission bank = 1.2040e-01 seconds
#      Sampling source sites         = 1.0123e-01 seconds
#      SEND/RECV source sites        = 1.8841e-02 seconds
#    Time accumulating tallies       = 4.2560e-05 seconds
#    Time writing statepoints        = 7.6624e-03 seconds
#  Total time for finalization       = 1.0520e-06 seconds
#  Total time elapsed                = 8.1915e+00 seconds
#  Calculation Rate (inactive)       = 259748 particles/second
#  Calculation Rate (active)         = 262785 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06608 +/- 0.00137
#  k-effective (Track-length)  = 1.06678 +/- 0.00166
#  k-effective (Absorption)    = 1.06503 +/- 0.00153
#  Combined k-effective        = 1.06527 +/- 0.00132
#  Leakage Fraction            = 0.13941 +/- 0.00042
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:27:30
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8181e+00 seconds
#    Reading cross sections          = 3.7940e+00 seconds
#  Total time in simulation          = 4.1517e+00 seconds
#    Time in transport only          = 3.9641e+00 seconds
#    Time in inactive batches        = 1.4128e+00 seconds
#    Time in active batches          = 2.7389e+00 seconds
#    Time synchronizing fission bank = 1.2051e-01 seconds
#      Sampling source sites         = 9.7455e-02 seconds
#      SEND/RECV source sites        = 2.2704e-02 seconds
#    Time accumulating tallies       = 5.4248e-05 seconds
#    Time writing statepoints        = 5.3921e-03 seconds
#  Total time for finalization       = 9.3200e-07 seconds
#  Total time elapsed                = 8.0388e+00 seconds
#  Calculation Rate (inactive)       = 265433 particles/second
#  Calculation Rate (active)         = 273834 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.07301 +/- 0.00176
#  k-effective (Track-length)  = 1.07319 +/- 0.00195
#  k-effective (Absorption)    = 1.07402 +/- 0.00106
#  Combined k-effective        = 1.07382 +/- 0.00106
#  Leakage Fraction            = 0.13354 +/- 0.00047
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:28:20
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.08363
#         2/1    1.08327
#         3/1    1.06029
#         4/1    1.08713
#         5/1    1.06702
#         6/1    1.07774
#         7/1    1.08017
#         8/1    1.08988
#         9/1    1.07100
#        10/1    1.08036
#        11/1    1.08776
#        12/1    1.09345
#        13/1    1.06443
#        14/1    1.08838
#        15/1    1.06938
#        16/1    1.06851
#        17/1    1.06469    1.06660 +/- 0.00191
#        18/1    1.08503    1.07274 +/- 0.00624
#        19/1    1.07890    1.07428 +/- 0.00467
#        20/1    1.07978    1.07538 +/- 0.00378
#        21/1    1.09436    1.07854 +/- 0.00442
#        22/1    1.08036    1.07880 +/- 0.00375
#        23/1    1.05885    1.07631 +/- 0.00409
#        24/1    1.07120    1.07574 +/- 0.00365
#        25/1    1.08920    1.07709 +/- 0.00353
#        26/1    1.05880    1.07543 +/- 0.00360
#        27/1    1.08315    1.07607 +/- 0.00335
#        28/1    1.07037    1.07563 +/- 0.00311
#        29/1    1.08840    1.07654 +/- 0.00302
#        30/1    1.09834    1.07800 +/- 0.00317
#        31/1    1.06536    1.07721 +/- 0.00307
#        32/1    1.08297    1.07755 +/- 0.00290
#        33/1    1.06729    1.07698 +/- 0.00279
#        34/1    1.08858    1.07759 +/- 0.00271
#        35/1    1.07571    1.07749 +/- 0.00257
#        36/1    1.06373    1.07684 +/- 0.00253
#        37/1    1.06217    1.07617 +/- 0.00251
#        38/1    1.06373    1.07563 +/- 0.00246
#        39/1    1.07564    1.07563 +/- 0.00235
#        40/1    1.07465    1.07559 +/- 0.00226
#        41/1    1.06854    1.07532 +/- 0.00218
#        42/1    1.08137    1.07554 +/- 0.00211
#        43/1    1.08504    1.07588 +/- 0.00206
#        44/1    1.07410    1.07582 +/- 0.00199
#        45/1    1.10238    1.07671 +/- 0.00212
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.6446e+00 seconds
#    Reading cross sections          = 3.6210e+00 seconds
#  Total time in simulation          = 4.1734e+00 seconds
#    Time in transport only          = 4.0021e+00 seconds
#    Time in inactive batches        = 1.3943e+00 seconds
#    Time in active batches          = 2.7791e+00 seconds
#    Time synchronizing fission bank = 1.0729e-01 seconds
#      Sampling source sites         = 8.2370e-02 seconds
#      SEND/RECV source sites        = 2.4592e-02 seconds
#    Time accumulating tallies       = 3.8366e-05 seconds
#    Time writing statepoints        = 7.8765e-03 seconds
#  Total time for finalization       = 8.4500e-07 seconds
#  Total time elapsed                = 7.8468e+00 seconds
#  Calculation Rate (inactive)       = 268953 particles/second
#  Calculation Rate (active)         = 269871 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.07575 +/- 0.00214
#  k-effective (Track-length)  = 1.07671 +/- 0.00212
#  k-effective (Absorption)    = 1.07602 +/- 0.00122
#  Combined k-effective        = 1.07608 +/- 0.00132
#  Leakage Fraction            = 0.13237 +/- 0.00038
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:28:28
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for C13
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.10226
#         2/1    1.04974
#         3/1    1.04811
#         4/1    1.06253
#         5/1    1.08075
#         6/1    1.07610
#         7/1    1.06064
#         8/1    1.08158
#         9/1    1.08053
#        10/1    1.07705
#        11/1    1.07835
#        12/1    1.07794
#        13/1    1.05847
#        14/1    1.07494
#        15/1    1.07742
#        16/1    1.07081
#        17/1    1.06838    1.06960 +/- 0.00121
#        18/1    1.07519    1.07146 +/- 0.00199
#        19/1    1.07227    1.07166 +/- 0.00142
#        20/1    1.08634    1.07460 +/- 0.00314
#        21/1    1.06690    1.07332 +/- 0.00286
#        22/1    1.08391    1.07483 +/- 0.00285
#        23/1    1.08873    1.07657 +/- 0.00302
#        24/1    1.07924    1.07686 +/- 0.00268
#        25/1    1.08641    1.07782 +/- 0.00258
#        26/1    1.06229    1.07641 +/- 0.00273
#        27/1    1.07749    1.07650 +/- 0.00249
#        28/1    1.07265    1.07620 +/- 0.00231
#        29/1    1.08821    1.07706 +/- 0.00231
#        30/1    1.05741    1.07575 +/- 0.00251
#        31/1    1.05762    1.07462 +/- 0.00261
#        32/1    1.08902    1.07546 +/- 0.00259
#        33/1    1.10365    1.07703 +/- 0.00290
#        34/1    1.07627    1.07699 +/- 0.00275
#        35/1    1.06828    1.07655 +/- 0.00264
#        36/1    1.07169    1.07632 +/- 0.00252
#        37/1    1.06760    1.07593 +/- 0.00244
#        38/1    1.07309    1.07580 +/- 0.00233
#        39/1    1.07138    1.07562 +/- 0.00224
#        40/1    1.06216    1.07508 +/- 0.00222
#        41/1    1.07715    1.07516 +/- 0.00213
#        42/1    1.07579    1.07518 +/- 0.00205
#        43/1    1.05988    1.07464 +/- 0.00205
#        44/1    1.06775    1.07440 +/- 0.00199
#        45/1    1.07795    1.07452 +/- 0.00193
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8069e+00 seconds
#    Reading cross sections          = 3.7832e+00 seconds
#  Total time in simulation          = 4.2022e+00 seconds
#    Time in transport only          = 3.9979e+00 seconds
#    Time in inactive batches        = 1.4087e+00 seconds
#    Time in active batches          = 2.7935e+00 seconds
#    Time synchronizing fission bank = 1.1872e-01 seconds
#      Sampling source sites         = 9.9485e-02 seconds
#      SEND/RECV source sites        = 1.8897e-02 seconds
#    Time accumulating tallies       = 4.2828e-05 seconds
#    Time writing statepoints        = 1.6867e-02 seconds
#  Total time for finalization       = 1.0810e-06 seconds
#  Total time elapsed                = 8.0484e+00 seconds
#  Calculation Rate (inactive)       = 266195 particles/second
#  Calculation Rate (active)         = 268482 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.07420 +/- 0.00150
#  k-effective (Track-length)  = 1.07452 +/- 0.00193
#  k-effective (Absorption)    = 1.07503 +/- 0.00116
#  Combined k-effective        = 1.07474 +/- 0.00115
#  Leakage Fraction            = 0.13240 +/- 0.00043

# %%
plt.errorbar(np.array(trisoPkFrac), np.array(k_eff_tPkFrac),np.array(kitPF))
# Out:
# <ErrorbarContainer object of 3 artists>
