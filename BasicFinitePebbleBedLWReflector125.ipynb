# %%
import openmc
import openmc.deplete
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi
import xml.etree.ElementTree as et
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
trisoPkFrac = 0.3
pebblePkFrac = 0.64

reflctThickness = 125;

erchPercent = range(5,21)
U_form = 1;
O_form = 2;
rho_fuel = 10.96; # g/cm3

trisoPartThicknesses = [253.5, 97.7, 41.9, 37.5, 45.6]; #um

coolTemp = 450+273.15 #C -> K
coolPres = 8 #MPa

# %%
#      Buffer
buffer = openmc.Material(name='Buffer')
buffer.set_density('g/cm3', 1.0)
buffer.add_element('C', 1.0)
#buffer.add_s_alpha_beta('c_Graphite')

#      IPyC
IPyC = openmc.Material(name='IPyC')
IPyC.set_density('g/cm3', 1.9)
IPyC.add_element('C', 1.0)
#IPyC.add_s_alpha_beta('c_Graphite')

#      SiC
SiC = openmc.Material(name='SiC')
SiC.set_density('g/cm3', 3.2)
SiC.add_element('C', 0.5)
SiC.add_element('Si', 0.5)

#      OPyC
OPyC = openmc.Material(name='OPyC')
OPyC.set_density('g/cm3', 1.87)
OPyC.add_element('C', 1.0)
#OPyC.add_s_alpha_beta('c_Graphite')

# Moderator
graphite = openmc.Material()
graphite.set_density('g/cm3', 1.1995)
graphite.add_element('C', 1.0)
#graphite.add_s_alpha_beta('c_Graphite')

# Coolant
He = openmc.Material(name='He')
He.set_density('g/cm3',coolPres/coolTemp/2.0771)
He.add_element('He',1.0)
He.temperature = coolTemp

# Reflector
Refl = openmc.Material(name='Reflector')
Refl.set_density('g/cm3',1)
Refl.add_element('H',2)
Refl.add_element('O',1)
Refl.add_s_alpha_beta('c_H_in_H2O')

# %%
#B5
trisoPartRads = trisoPartThicknesses
for i in range(1,5):
    trisoPartRads[i] += trisoPartRads[i-1]
trisoPartVolFracs = trisoPartRads
for i in range(5):
    trisoPartVolFracs[i] = (trisoPartRads[i]/trisoPartRads[4])**3
for i in range(4):
    trisoPartVolFracs[4-i] -= trisoPartVolFracs[3-i]

# %%
#B6
pebbleRads = [25, 30]
pebbleVolFracs = pebbleRads
for i in range(2):
    pebbleVolFracs[i] = (pebbleRads[i]/pebbleRads[1])**3
pebbleVolFracs[1] -= pebbleVolFracs[0]

# %%
trisoPkFrac = range(30,60,2)
erchPercent = .1975

# %%
#      Fuel Kernel
fuel = openmc.Material(name="fuel")
fuel.set_density('g/cm3', rho_fuel)
fuel.add_nuclide('U235',erchPercent*U_form/(U_form+O_form))
fuel.add_nuclide('U238',((1-erchPercent)*U_form/(U_form+O_form)))
fuel.add_element('O', O_form/(U_form+O_form))
homogTrisoPart = openmc.Material.mix_materials([fuel, buffer, IPyC, SiC, OPyC], trisoPartVolFracs, 'vo')

# %%
#Enrichment Optimization
k_eff_tPkFrac = []
kitPF = []
for eki in trisoPkFrac:
    #B4
    homogTrisoPebCore = openmc.Material.mix_materials([homogTrisoPart,graphite], [eki/100, 1-eki/100], 'vo');
    homogTrisoPebble = openmc.Material.mix_materials([homogTrisoPebCore, graphite], pebbleVolFracs, 'vo');


    #B7
    homogCore = openmc.Material.mix_materials([homogTrisoPebble, He], [pebblePkFrac, 1-pebblePkFrac], 'vo')
    homogCore.add_s_alpha_beta('c_Graphite')
    materials = openmc.Materials()
    materials += [Refl, homogCore]
    materials.export_to_xml()
    
        #B8
    core = openmc.model.RightCircularCylinder([0,0,0], 125, 50, axis='z', boundary_type = 'transmission')
    rflctr = openmc.model.RightCircularCylinder([0,0,-reflctThickness],2*reflctThickness+125,reflctThickness+50, axis ='z',boundary_type = 'vacuum') 
    rxr = openmc.Cell(fill=homogCore, region=-core)
    reflect = openmc.Cell(fill = Refl, region =+core&-rflctr)
    surr = openmc.Cell(region =+rflctr)
    universe = openmc.Universe(cells=[rxr, reflect, surr])
    geometry = openmc.Geometry()
    geometry.root_universe = universe
    geometry.export_to_xml()
    settings = openmc.Settings()
    settings.run_mode = 'eigenvalue'
    settings.particles = 25000
    settings.batches = 45
    settings.inactive = 15
    settings.temperature={'method':'interpolation','range':(250,2500)}
    settings.export_to_xml()

    

    #B9
    num_threads_des = 136  # set as desired.  Can be useful to ensure you do not take over all the resources for a machine
    num_threads = min(os.cpu_count(),num_threads_des); # prevent asking for more threads than OMP_NUM_THREADS
    
    openmc.run(threads = num_threads, output=True)
    sp = openmc.StatePoint('statepoint.45.h5')
    keff = sp.keff
    k_eff_tPkFrac.append(keff.n)
    kitPF.append(keff.s)
    sp.close()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:56:10
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.63852
#         2/1    0.64540
#         3/1    0.62181
#         4/1    0.61061
#         5/1    0.63204
#         6/1    0.60574
#         7/1    0.64041
#         8/1    0.62707
#         9/1    0.63300
#        10/1    0.64198
#        11/1    0.64207
#        12/1    0.64653
#        13/1    0.62664
#        14/1    0.62987
#        15/1    0.63837
#        16/1    0.64968
#        17/1    0.63717    0.64342 +/- 0.00625
#        18/1    0.62482    0.63722 +/- 0.00717
#        19/1    0.63103    0.63567 +/- 0.00530
#        20/1    0.62194    0.63293 +/- 0.00494
#        21/1    0.62006    0.63078 +/- 0.00457
#        22/1    0.64575    0.63292 +/- 0.00441
#        23/1    0.62640    0.63211 +/- 0.00391
#        24/1    0.62316    0.63111 +/- 0.00359
#        25/1    0.63339    0.63134 +/- 0.00322
#        26/1    0.63007    0.63122 +/- 0.00291
#        27/1    0.63641    0.63166 +/- 0.00269
#        28/1    0.63111    0.63161 +/- 0.00248
#        29/1    0.62319    0.63101 +/- 0.00237
#        30/1    0.61476    0.62993 +/- 0.00246
#        31/1    0.62967    0.62991 +/- 0.00230
#        32/1    0.63095    0.62997 +/- 0.00216
#        33/1    0.62457    0.62967 +/- 0.00206
#        34/1    0.63469    0.62994 +/- 0.00197
#        35/1    0.63024    0.62995 +/- 0.00187
#        36/1    0.61039    0.62902 +/- 0.00200
#        37/1    0.62686    0.62892 +/- 0.00191
#        38/1    0.62715    0.62885 +/- 0.00183
#        39/1    0.64295    0.62943 +/- 0.00185
#        40/1    0.62999    0.62946 +/- 0.00177
#        41/1    0.62600    0.62932 +/- 0.00171
#        42/1    0.62871    0.62930 +/- 0.00164
#        43/1    0.63637    0.62955 +/- 0.00160
#        44/1    0.62736    0.62948 +/- 0.00155
#        45/1    0.62649    0.62938 +/- 0.00150
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.5386e+00 seconds
#    Reading cross sections          = 6.5094e+00 seconds
#  Total time in simulation          = 3.1546e+00 seconds
#    Time in transport only          = 2.9535e+00 seconds
#    Time in inactive batches        = 1.0931e+00 seconds
#    Time in active batches          = 2.0614e+00 seconds
#    Time synchronizing fission bank = 1.1602e-01 seconds
#      Sampling source sites         = 9.5773e-02 seconds
#      SEND/RECV source sites        = 1.9929e-02 seconds
#    Time accumulating tallies       = 4.5982e-05 seconds
#    Time writing statepoints        = 1.5662e-02 seconds
#  Total time for finalization       = 1.1400e-06 seconds
#  Total time elapsed                = 9.7333e+00 seconds
#  Calculation Rate (inactive)       = 343055 particles/second
#  Calculation Rate (active)         = 363823 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.62952 +/- 0.00141
#  k-effective (Track-length)  = 0.62938 +/- 0.00150
#  k-effective (Absorption)    = 0.63047 +/- 0.00092
#  Combined k-effective        = 0.63040 +/- 0.00096
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:56:20
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.64082
#         2/1    0.66257
#         3/1    0.62565
#         4/1    0.63068
#         5/1    0.63830
#         6/1    0.64049
#         7/1    0.63324
#         8/1    0.63924
#         9/1    0.64660
#        10/1    0.63729
#        11/1    0.64832
#        12/1    0.63649
#        13/1    0.63274
#        14/1    0.62978
#        15/1    0.64385
#        16/1    0.62162
#        17/1    0.63102    0.62632 +/- 0.00470
#        18/1    0.64482    0.63248 +/- 0.00674
#        19/1    0.63953    0.63425 +/- 0.00508
#        20/1    0.64563    0.63652 +/- 0.00455
#        21/1    0.65231    0.63915 +/- 0.00455
#        22/1    0.64033    0.63932 +/- 0.00385
#        23/1    0.63075    0.63825 +/- 0.00350
#        24/1    0.64687    0.63921 +/- 0.00323
#        25/1    0.64802    0.64009 +/- 0.00302
#        26/1    0.64756    0.64077 +/- 0.00282
#        27/1    0.65182    0.64169 +/- 0.00273
#        28/1    0.62579    0.64047 +/- 0.00279
#        29/1    0.63354    0.63997 +/- 0.00263
#        30/1    0.63585    0.63970 +/- 0.00247
#        31/1    0.62660    0.63888 +/- 0.00245
#        32/1    0.62884    0.63829 +/- 0.00238
#        33/1    0.62786    0.63771 +/- 0.00231
#        34/1    0.63451    0.63754 +/- 0.00219
#        35/1    0.64284    0.63781 +/- 0.00210
#        36/1    0.62312    0.63711 +/- 0.00212
#        37/1    0.62640    0.63662 +/- 0.00207
#        38/1    0.62712    0.63621 +/- 0.00203
#        39/1    0.64504    0.63657 +/- 0.00197
#        40/1    0.63986    0.63671 +/- 0.00190
#        41/1    0.63203    0.63653 +/- 0.00183
#        42/1    0.64876    0.63698 +/- 0.00182
#        43/1    0.63498    0.63691 +/- 0.00176
#        44/1    0.64035    0.63703 +/- 0.00170
#        45/1    0.63819    0.63707 +/- 0.00164
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.5389e+00 seconds
#    Reading cross sections          = 5.5109e+00 seconds
#  Total time in simulation          = 3.1239e+00 seconds
#    Time in transport only          = 2.9553e+00 seconds
#    Time in inactive batches        = 1.0642e+00 seconds
#    Time in active batches          = 2.0598e+00 seconds
#    Time synchronizing fission bank = 9.9507e-02 seconds
#      Sampling source sites         = 8.1763e-02 seconds
#      SEND/RECV source sites        = 1.7434e-02 seconds
#    Time accumulating tallies       = 3.9408e-05 seconds
#    Time writing statepoints        = 1.4310e-02 seconds
#  Total time for finalization       = 1.0220e-06 seconds
#  Total time elapsed                = 8.7044e+00 seconds
#  Calculation Rate (inactive)       = 352386 particles/second
#  Calculation Rate (active)         = 364120 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.63651 +/- 0.00153
#  k-effective (Track-length)  = 0.63707 +/- 0.00164
#  k-effective (Absorption)    = 0.63638 +/- 0.00108
#  Combined k-effective        = 0.63641 +/- 0.00111
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:56:29
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.63824
#         2/1    0.65665
#         3/1    0.63662
#         4/1    0.63169
#         5/1    0.62207
#         6/1    0.62706
#         7/1    0.63345
#         8/1    0.64415
#         9/1    0.63842
#        10/1    0.64706
#        11/1    0.64159
#        12/1    0.63434
#        13/1    0.62283
#        14/1    0.63964
#        15/1    0.64788
#        16/1    0.63946
#        17/1    0.62603    0.63275 +/- 0.00672
#        18/1    0.62892    0.63147 +/- 0.00408
#        19/1    0.64834    0.63569 +/- 0.00511
#        20/1    0.65002    0.63856 +/- 0.00489
#        21/1    0.64023    0.63883 +/- 0.00400
#        22/1    0.64601    0.63986 +/- 0.00353
#        23/1    0.62883    0.63848 +/- 0.00336
#        24/1    0.63995    0.63864 +/- 0.00296
#        25/1    0.63410    0.63819 +/- 0.00269
#        26/1    0.64482    0.63879 +/- 0.00251
#        27/1    0.64706    0.63948 +/- 0.00239
#        28/1    0.62720    0.63854 +/- 0.00239
#        29/1    0.63155    0.63804 +/- 0.00227
#        30/1    0.63291    0.63770 +/- 0.00214
#        31/1    0.63861    0.63775 +/- 0.00200
#        32/1    0.63737    0.63773 +/- 0.00188
#        33/1    0.62331    0.63693 +/- 0.00195
#        34/1    0.63240    0.63669 +/- 0.00186
#        35/1    0.65002    0.63736 +/- 0.00188
#        36/1    0.63448    0.63722 +/- 0.00180
#        37/1    0.65248    0.63791 +/- 0.00185
#        38/1    0.64451    0.63820 +/- 0.00179
#        39/1    0.65348    0.63884 +/- 0.00183
#        40/1    0.63521    0.63869 +/- 0.00176
#        41/1    0.64871    0.63908 +/- 0.00173
#        42/1    0.64162    0.63917 +/- 0.00167
#        43/1    0.62376    0.63862 +/- 0.00170
#        44/1    0.61465    0.63780 +/- 0.00184
#        45/1    0.63943    0.63785 +/- 0.00178
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.4865e+00 seconds
#    Reading cross sections          = 5.4567e+00 seconds
#  Total time in simulation          = 3.0880e+00 seconds
#    Time in transport only          = 2.9246e+00 seconds
#    Time in inactive batches        = 1.0306e+00 seconds
#    Time in active batches          = 2.0574e+00 seconds
#    Time synchronizing fission bank = 1.0179e-01 seconds
#      Sampling source sites         = 8.0684e-02 seconds
#      SEND/RECV source sites        = 2.0785e-02 seconds
#    Time accumulating tallies       = 4.7880e-05 seconds
#    Time writing statepoints        = 8.2488e-03 seconds
#  Total time for finalization       = 7.7900e-07 seconds
#  Total time elapsed                = 8.6357e+00 seconds
#  Calculation Rate (inactive)       = 363873 particles/second
#  Calculation Rate (active)         = 364538 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.63801 +/- 0.00173
#  k-effective (Track-length)  = 0.63785 +/- 0.00178
#  k-effective (Absorption)    = 0.63985 +/- 0.00121
#  Combined k-effective        = 0.64000 +/- 0.00130
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:56:38
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.64290
#         2/1    0.66674
#         3/1    0.63104
#         4/1    0.63391
#         5/1    0.64737
#         6/1    0.63772
#         7/1    0.63751
#         8/1    0.63676
#         9/1    0.65317
#        10/1    0.64125
#        11/1    0.65423
#        12/1    0.65047
#        13/1    0.64791
#        14/1    0.63728
#        15/1    0.63110
#        16/1    0.63527
#        17/1    0.64368    0.63948 +/- 0.00421
#        18/1    0.63668    0.63854 +/- 0.00260
#        19/1    0.65422    0.64246 +/- 0.00433
#        20/1    0.64425    0.64282 +/- 0.00337
#        21/1    0.65149    0.64427 +/- 0.00311
#        22/1    0.64557    0.64445 +/- 0.00263
#        23/1    0.65769    0.64611 +/- 0.00282
#        24/1    0.64788    0.64630 +/- 0.00249
#        25/1    0.65243    0.64692 +/- 0.00231
#        26/1    0.64645    0.64687 +/- 0.00209
#        27/1    0.64259    0.64652 +/- 0.00194
#        28/1    0.64477    0.64638 +/- 0.00179
#        29/1    0.64668    0.64640 +/- 0.00166
#        30/1    0.65495    0.64697 +/- 0.00165
#        31/1    0.63902    0.64648 +/- 0.00162
#        32/1    0.64687    0.64650 +/- 0.00152
#        33/1    0.64861    0.64662 +/- 0.00144
#        34/1    0.65383    0.64700 +/- 0.00141
#        35/1    0.63846    0.64657 +/- 0.00141
#        36/1    0.65343    0.64690 +/- 0.00138
#        37/1    0.64839    0.64696 +/- 0.00131
#        38/1    0.64197    0.64675 +/- 0.00127
#        39/1    0.65302    0.64701 +/- 0.00125
#        40/1    0.63469    0.64652 +/- 0.00129
#        41/1    0.63826    0.64620 +/- 0.00128
#        42/1    0.64359    0.64610 +/- 0.00124
#        43/1    0.63474    0.64570 +/- 0.00126
#        44/1    0.63648    0.64538 +/- 0.00126
#        45/1    0.64805    0.64547 +/- 0.00122
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.4522e+00 seconds
#    Reading cross sections          = 5.4252e+00 seconds
#  Total time in simulation          = 3.1055e+00 seconds
#    Time in transport only          = 2.9494e+00 seconds
#    Time in inactive batches        = 1.0587e+00 seconds
#    Time in active batches          = 2.0468e+00 seconds
#    Time synchronizing fission bank = 1.0011e-01 seconds
#      Sampling source sites         = 7.8122e-02 seconds
#      SEND/RECV source sites        = 2.1705e-02 seconds
#    Time accumulating tallies       = 3.5131e-05 seconds
#    Time writing statepoints        = 7.3334e-03 seconds
#  Total time for finalization       = 7.9300e-07 seconds
#  Total time elapsed                = 8.5973e+00 seconds
#  Calculation Rate (inactive)       = 354205 particles/second
#  Calculation Rate (active)         = 366422 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.64512 +/- 0.00130
#  k-effective (Track-length)  = 0.64547 +/- 0.00122
#  k-effective (Absorption)    = 0.64413 +/- 0.00086
#  Combined k-effective        = 0.64442 +/- 0.00089
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:56:46
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.64433
#         2/1    0.65727
#         3/1    0.63386
#         4/1    0.64584
#         5/1    0.65039
#         6/1    0.64733
#         7/1    0.64552
#         8/1    0.66315
#         9/1    0.63860
#        10/1    0.65854
#        11/1    0.65416
#        12/1    0.65896
#        13/1    0.65479
#        14/1    0.65434
#        15/1    0.65143
#        16/1    0.66230
#        17/1    0.63844    0.65037 +/- 0.01193
#        18/1    0.63108    0.64394 +/- 0.00942
#        19/1    0.65102    0.64571 +/- 0.00689
#        20/1    0.63959    0.64449 +/- 0.00548
#        21/1    0.64982    0.64537 +/- 0.00456
#        22/1    0.64878    0.64586 +/- 0.00388
#        23/1    0.64037    0.64517 +/- 0.00343
#        24/1    0.65957    0.64677 +/- 0.00342
#        25/1    0.64798    0.64689 +/- 0.00307
#        26/1    0.65474    0.64761 +/- 0.00286
#        27/1    0.63853    0.64685 +/- 0.00272
#        28/1    0.65259    0.64729 +/- 0.00254
#        29/1    0.64204    0.64692 +/- 0.00238
#        30/1    0.63787    0.64631 +/- 0.00230
#        31/1    0.64352    0.64614 +/- 0.00216
#        32/1    0.64404    0.64602 +/- 0.00203
#        33/1    0.64356    0.64588 +/- 0.00192
#        34/1    0.65342    0.64628 +/- 0.00186
#        35/1    0.64890    0.64641 +/- 0.00177
#        36/1    0.64378    0.64628 +/- 0.00169
#        37/1    0.65116    0.64650 +/- 0.00162
#        38/1    0.63203    0.64587 +/- 0.00167
#        39/1    0.63074    0.64524 +/- 0.00172
#        40/1    0.64001    0.64503 +/- 0.00166
#        41/1    0.64487    0.64503 +/- 0.00160
#        42/1    0.65621    0.64544 +/- 0.00159
#        43/1    0.64627    0.64547 +/- 0.00154
#        44/1    0.65174    0.64569 +/- 0.00150
#        45/1    0.64671    0.64572 +/- 0.00145
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.4160e+00 seconds
#    Reading cross sections          = 5.3874e+00 seconds
#  Total time in simulation          = 3.0413e+00 seconds
#    Time in transport only          = 2.8862e+00 seconds
#    Time in inactive batches        = 1.0201e+00 seconds
#    Time in active batches          = 2.0212e+00 seconds
#    Time synchronizing fission bank = 9.8063e-02 seconds
#      Sampling source sites         = 7.6498e-02 seconds
#      SEND/RECV source sites        = 2.1267e-02 seconds
#    Time accumulating tallies       = 3.7774e-05 seconds
#    Time writing statepoints        = 7.1292e-03 seconds
#  Total time for finalization       = 9.6700e-07 seconds
#  Total time elapsed                = 8.4963e+00 seconds
#  Calculation Rate (inactive)       = 367603 particles/second
#  Calculation Rate (active)         = 371068 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.64604 +/- 0.00133
#  k-effective (Track-length)  = 0.64572 +/- 0.00145
#  k-effective (Absorption)    = 0.64583 +/- 0.00086
#  Combined k-effective        = 0.64574 +/- 0.00089
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:56:55
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.64670
#         2/1    0.67499
#         3/1    0.65837
#         4/1    0.64136
#         5/1    0.65956
#         6/1    0.64039
#         7/1    0.64857
#         8/1    0.65063
#         9/1    0.65488
#        10/1    0.63050
#        11/1    0.65992
#        12/1    0.65540
#        13/1    0.65239
#        14/1    0.66019
#        15/1    0.66041
#        16/1    0.64031
#        17/1    0.65737    0.64884 +/- 0.00853
#        18/1    0.66824    0.65531 +/- 0.00813
#        19/1    0.65801    0.65598 +/- 0.00579
#        20/1    0.67583    0.65995 +/- 0.00599
#        21/1    0.65148    0.65854 +/- 0.00509
#        22/1    0.66329    0.65922 +/- 0.00435
#        23/1    0.65773    0.65903 +/- 0.00378
#        24/1    0.66165    0.65932 +/- 0.00334
#        25/1    0.65373    0.65876 +/- 0.00304
#        26/1    0.64029    0.65708 +/- 0.00322
#        27/1    0.64260    0.65588 +/- 0.00318
#        28/1    0.64294    0.65488 +/- 0.00309
#        29/1    0.67027    0.65598 +/- 0.00306
#        30/1    0.65945    0.65621 +/- 0.00286
#        31/1    0.65470    0.65612 +/- 0.00268
#        32/1    0.63723    0.65501 +/- 0.00275
#        33/1    0.65906    0.65523 +/- 0.00260
#        34/1    0.64053    0.65446 +/- 0.00258
#        35/1    0.65176    0.65432 +/- 0.00245
#        36/1    0.66545    0.65485 +/- 0.00239
#        37/1    0.63996    0.65418 +/- 0.00238
#        38/1    0.64928    0.65396 +/- 0.00228
#        39/1    0.64776    0.65371 +/- 0.00220
#        40/1    0.65797    0.65388 +/- 0.00212
#        41/1    0.65178    0.65380 +/- 0.00204
#        42/1    0.64386    0.65343 +/- 0.00199
#        43/1    0.64560    0.65315 +/- 0.00194
#        44/1    0.65189    0.65310 +/- 0.00187
#        45/1    0.64253    0.65275 +/- 0.00184
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.4136e+00 seconds
#    Reading cross sections          = 5.3864e+00 seconds
#  Total time in simulation          = 3.0378e+00 seconds
#    Time in transport only          = 2.8839e+00 seconds
#    Time in inactive batches        = 1.0244e+00 seconds
#    Time in active batches          = 2.0134e+00 seconds
#    Time synchronizing fission bank = 9.8505e-02 seconds
#      Sampling source sites         = 7.6681e-02 seconds
#      SEND/RECV source sites        = 2.1516e-02 seconds
#    Time accumulating tallies       = 3.2418e-05 seconds
#    Time writing statepoints        = 7.3466e-03 seconds
#  Total time for finalization       = 8.2200e-07 seconds
#  Total time elapsed                = 8.4921e+00 seconds
#  Calculation Rate (inactive)       = 366066 particles/second
#  Calculation Rate (active)         = 372509 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.65442 +/- 0.00155
#  k-effective (Track-length)  = 0.65275 +/- 0.00184
#  k-effective (Absorption)    = 0.65231 +/- 0.00116
#  Combined k-effective        = 0.65254 +/- 0.00149
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:57:04
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.64909
#         2/1    0.66922
#         3/1    0.64106
#         4/1    0.64565
#         5/1    0.66085
#         6/1    0.65295
#         7/1    0.65488
#         8/1    0.65498
#         9/1    0.66640
#        10/1    0.64573
#        11/1    0.66360
#        12/1    0.65133
#        13/1    0.66741
#        14/1    0.67384
#        15/1    0.65636
#        16/1    0.64037
#        17/1    0.64814    0.64425 +/- 0.00389
#        18/1    0.65975    0.64942 +/- 0.00563
#        19/1    0.65267    0.65023 +/- 0.00406
#        20/1    0.66978    0.65414 +/- 0.00502
#        21/1    0.65861    0.65489 +/- 0.00417
#        22/1    0.65522    0.65493 +/- 0.00352
#        23/1    0.65033    0.65436 +/- 0.00310
#        24/1    0.65458    0.65438 +/- 0.00274
#        25/1    0.64811    0.65375 +/- 0.00253
#        26/1    0.65250    0.65364 +/- 0.00229
#        27/1    0.66028    0.65419 +/- 0.00216
#        28/1    0.65553    0.65430 +/- 0.00199
#        29/1    0.65859    0.65460 +/- 0.00187
#        30/1    0.65403    0.65457 +/- 0.00174
#        31/1    0.65666    0.65470 +/- 0.00163
#        32/1    0.64181    0.65394 +/- 0.00171
#        33/1    0.64878    0.65365 +/- 0.00164
#        34/1    0.65822    0.65389 +/- 0.00157
#        35/1    0.65538    0.65397 +/- 0.00149
#        36/1    0.65395    0.65397 +/- 0.00142
#        37/1    0.63992    0.65333 +/- 0.00149
#        38/1    0.65876    0.65356 +/- 0.00145
#        39/1    0.64761    0.65332 +/- 0.00141
#        40/1    0.63202    0.65246 +/- 0.00160
#        41/1    0.67316    0.65326 +/- 0.00173
#        42/1    0.66011    0.65351 +/- 0.00168
#        43/1    0.64700    0.65328 +/- 0.00164
#        44/1    0.65819    0.65345 +/- 0.00159
#        45/1    0.63691    0.65290 +/- 0.00163
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.4223e+00 seconds
#    Reading cross sections          = 5.3945e+00 seconds
#  Total time in simulation          = 3.0463e+00 seconds
#    Time in transport only          = 2.8598e+00 seconds
#    Time in inactive batches        = 1.0246e+00 seconds
#    Time in active batches          = 2.0217e+00 seconds
#    Time synchronizing fission bank = 1.0873e-01 seconds
#      Sampling source sites         = 8.8373e-02 seconds
#      SEND/RECV source sites        = 2.0056e-02 seconds
#    Time accumulating tallies       = 3.9771e-05 seconds
#    Time writing statepoints        = 1.4186e-02 seconds
#  Total time for finalization       = 1.2060e-06 seconds
#  Total time elapsed                = 8.5094e+00 seconds
#  Calculation Rate (inactive)       = 365990 particles/second
#  Calculation Rate (active)         = 370977 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.65328 +/- 0.00135
#  k-effective (Track-length)  = 0.65290 +/- 0.00163
#  k-effective (Absorption)    = 0.65337 +/- 0.00129
#  Combined k-effective        = 0.65363 +/- 0.00110
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:57:13
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
# ...
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.67218
#         2/1    0.69073
#         3/1    0.67525
#         4/1    0.66843
#         5/1    0.66901
#         6/1    0.66219
#         7/1    0.66285
#         8/1    0.66918
#         9/1    0.66680
#        10/1    0.67672
#        11/1    0.68812
#        12/1    0.66966
#        13/1    0.69756
#        14/1    0.67768
#        15/1    0.67299
#        16/1    0.66858
#        17/1    0.66497    0.66678 +/- 0.00181
#        18/1    0.66529    0.66628 +/- 0.00116
#        19/1    0.67836    0.66930 +/- 0.00313
#        20/1    0.67408    0.67026 +/- 0.00260
#        21/1    0.66930    0.67010 +/- 0.00213
#        22/1    0.66969    0.67004 +/- 0.00180
#        23/1    0.66846    0.66984 +/- 0.00157
#        24/1    0.67241    0.67013 +/- 0.00142
#        25/1    0.66626    0.66974 +/- 0.00133
#        26/1    0.67080    0.66984 +/- 0.00120
#        27/1    0.67156    0.66998 +/- 0.00111
#        28/1    0.66709    0.66976 +/- 0.00104
#        29/1    0.67005    0.66978 +/- 0.00097
#        30/1    0.67281    0.66998 +/- 0.00092
#        31/1    0.66886    0.66991 +/- 0.00086
#        32/1    0.67520    0.67022 +/- 0.00087
#        33/1    0.67195    0.67032 +/- 0.00083
#        34/1    0.67650    0.67064 +/- 0.00085
#        35/1    0.67718    0.67097 +/- 0.00087
#        36/1    0.66565    0.67072 +/- 0.00086
#        37/1    0.67709    0.67101 +/- 0.00087
#        38/1    0.67706    0.67127 +/- 0.00087
#        39/1    0.67432    0.67140 +/- 0.00085
#        40/1    0.68315    0.67187 +/- 0.00094
#        41/1    0.65859    0.67136 +/- 0.00104
#        42/1    0.65503    0.67075 +/- 0.00117
#        43/1    0.66419    0.67052 +/- 0.00115
#        44/1    0.67797    0.67077 +/- 0.00114
#        45/1    0.67307    0.67085 +/- 0.00110
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.3649e+00 seconds
#    Reading cross sections          = 5.3401e+00 seconds
#  Total time in simulation          = 2.9946e+00 seconds
#    Time in transport only          = 2.8159e+00 seconds
#    Time in inactive batches        = 9.9086e-01 seconds
#    Time in active batches          = 2.0038e+00 seconds
#    Time synchronizing fission bank = 1.0329e-01 seconds
#      Sampling source sites         = 8.4570e-02 seconds
#      SEND/RECV source sites        = 1.8430e-02 seconds
#    Time accumulating tallies       = 3.7095e-05 seconds
#    Time writing statepoints        = 1.4391e-02 seconds
#  Total time for finalization       = 1.0340e-06 seconds
#  Total time elapsed                = 8.3998e+00 seconds
#  Calculation Rate (inactive)       = 378459 particles/second
#  Calculation Rate (active)         = 374294 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.67093 +/- 0.00109
#  k-effective (Track-length)  = 0.67085 +/- 0.00110
#  k-effective (Absorption)    = 0.67249 +/- 0.00108
#  Combined k-effective        = 0.67171 +/- 0.00102
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:58:05
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.67231
#         2/1    0.68795
#         3/1    0.67961
#         4/1    0.68046
#         5/1    0.67339
#         6/1    0.68033
#         7/1    0.67447
#         8/1    0.67178
#         9/1    0.66828
#        10/1    0.66677
#        11/1    0.68419
#        12/1    0.67288
#        13/1    0.66476
#        14/1    0.67580
#        15/1    0.67481
#        16/1    0.67322
#        17/1    0.66752    0.67037 +/- 0.00285
#        18/1    0.66289    0.66788 +/- 0.00299
#        19/1    0.67649    0.67003 +/- 0.00302
#        20/1    0.68535    0.67309 +/- 0.00385
#        21/1    0.67792    0.67390 +/- 0.00325
#        22/1    0.67576    0.67416 +/- 0.00276
#        23/1    0.68459    0.67547 +/- 0.00272
#        24/1    0.67794    0.67574 +/- 0.00242
#        25/1    0.68035    0.67620 +/- 0.00221
#        26/1    0.67729    0.67630 +/- 0.00200
#        27/1    0.68025    0.67663 +/- 0.00186
#        28/1    0.67404    0.67643 +/- 0.00172
#        29/1    0.67673    0.67645 +/- 0.00159
#        30/1    0.66305    0.67556 +/- 0.00173
#        31/1    0.67952    0.67581 +/- 0.00164
#        32/1    0.66445    0.67514 +/- 0.00168
#        33/1    0.67805    0.67530 +/- 0.00159
#        34/1    0.66514    0.67477 +/- 0.00160
#        35/1    0.66763    0.67441 +/- 0.00155
#        36/1    0.67571    0.67447 +/- 0.00148
#        37/1    0.68747    0.67506 +/- 0.00153
#        38/1    0.67532    0.67507 +/- 0.00146
#        39/1    0.67119    0.67491 +/- 0.00141
#        40/1    0.66698    0.67459 +/- 0.00139
#        41/1    0.66011    0.67404 +/- 0.00145
#        42/1    0.66934    0.67386 +/- 0.00140
#        43/1    0.68033    0.67409 +/- 0.00137
#        44/1    0.68661    0.67453 +/- 0.00139
#        45/1    0.65360    0.67383 +/- 0.00151
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.3893e+00 seconds
#    Reading cross sections          = 5.3632e+00 seconds
#  Total time in simulation          = 3.0004e+00 seconds
#    Time in transport only          = 2.8448e+00 seconds
#    Time in inactive batches        = 1.0053e+00 seconds
#    Time in active batches          = 1.9951e+00 seconds
#    Time synchronizing fission bank = 9.8286e-02 seconds
#      Sampling source sites         = 7.7045e-02 seconds
#      SEND/RECV source sites        = 2.0950e-02 seconds
#    Time accumulating tallies       = 3.3443e-05 seconds
#    Time writing statepoints        = 7.8027e-03 seconds
#  Total time for finalization       = 7.7300e-07 seconds
#  Total time elapsed                = 8.4322e+00 seconds
#  Calculation Rate (inactive)       = 373020 particles/second
#  Calculation Rate (active)         = 375920 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.67423 +/- 0.00148
#  k-effective (Track-length)  = 0.67383 +/- 0.00151
#  k-effective (Absorption)    = 0.67516 +/- 0.00142
#  Combined k-effective        = 0.67472 +/- 0.00141
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 50e39a4e20dc9e0f3d7ccf07333f6a5e6c797c8c
#        Date/Time | 2024-02-09 00:58:13
#   OpenMP Threads | 136
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from /home/m245244/omc_data/lib80x_hdf5/H1.h5
#  Reading H2 from /home/m245244/omc_data/lib80x_hdf5/H2.h5
#  Reading O16 from /home/m245244/omc_data/lib80x_hdf5/O16.h5
#  Reading O17 from /home/m245244/omc_data/lib80x_hdf5/O17.h5
#  Reading O18 from /home/m245244/omc_data/lib80x_hdf5/O18.h5
#  Reading U235 from /home/m245244/omc_data/lib80x_hdf5/U235.h5
#  Reading U238 from /home/m245244/omc_data/lib80x_hdf5/U238.h5
#  Reading C12 from /home/m245244/omc_data/lib80x_hdf5/C12.h5
#  Reading C13 from /home/m245244/omc_data/lib80x_hdf5/C13.h5
#  Reading Si28 from /home/m245244/omc_data/lib80x_hdf5/Si28.h5
#  Reading Si29 from /home/m245244/omc_data/lib80x_hdf5/Si29.h5
#  Reading Si30 from /home/m245244/omc_data/lib80x_hdf5/Si30.h5
#  Reading He3 from /home/m245244/omc_data/lib80x_hdf5/He3.h5
#  Reading He4 from /home/m245244/omc_data/lib80x_hdf5/He4.h5
#  Reading c_H_in_H2O from /home/m245244/omc_data/lib80x_hdf5/c_H_in_H2O.h5
#  Reading c_Graphite from /home/m245244/omc_data/lib80x_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  WARNING: Could not find material 1 specified in plot 2
#  WARNING: Could not find material 2 specified in plot 2
#  WARNING: Could not find material 3 specified in plot 2
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.66957
#         2/1    0.70713
#         3/1    0.67816
#         4/1    0.67473
#         5/1    0.67724
#         6/1    0.68483
#         7/1    0.67555
#         8/1    0.68471
#         9/1    0.67588
#        10/1    0.67196
#        11/1    0.68230
#        12/1    0.68115
#        13/1    0.67263
#        14/1    0.66778
#        15/1    0.67473
#        16/1    0.66431
#        17/1    0.68889    0.67660 +/- 0.01229
#        18/1    0.67457    0.67592 +/- 0.00713
#        19/1    0.67334    0.67528 +/- 0.00508
#        20/1    0.67290    0.67480 +/- 0.00397
#        21/1    0.66771    0.67362 +/- 0.00345
#        22/1    0.67512    0.67383 +/- 0.00292
#        23/1    0.66722    0.67301 +/- 0.00266
#        24/1    0.66742    0.67239 +/- 0.00243
#        25/1    0.68153    0.67330 +/- 0.00236
#        26/1    0.68563    0.67442 +/- 0.00241
#        27/1    0.66701    0.67380 +/- 0.00228
#        28/1    0.67986    0.67427 +/- 0.00215
#        29/1    0.66950    0.67393 +/- 0.00202
#        30/1    0.67355    0.67390 +/- 0.00188
#        31/1    0.67433    0.67393 +/- 0.00176
#        32/1    0.67450    0.67396 +/- 0.00165
#        33/1    0.67233    0.67387 +/- 0.00156
#        34/1    0.67428    0.67390 +/- 0.00148
#        35/1    0.68491    0.67445 +/- 0.00151
#        36/1    0.66893    0.67418 +/- 0.00146
#        37/1    0.66594    0.67381 +/- 0.00144
#        38/1    0.66789    0.67355 +/- 0.00140
#        39/1    0.67980    0.67381 +/- 0.00136
#        40/1    0.67201    0.67374 +/- 0.00131
#        41/1    0.68556    0.67419 +/- 0.00134
#        42/1    0.68836    0.67472 +/- 0.00139
#        43/1    0.69009    0.67527 +/- 0.00145
#        44/1    0.66089    0.67477 +/- 0.00148
#        45/1    0.66626    0.67449 +/- 0.00146
#  Creating state point statepoint.45.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.3968e+00 seconds
#    Reading cross sections          = 5.3704e+00 seconds
#  Total time in simulation          = 3.0513e+00 seconds
#    Time in transport only          = 2.8909e+00 seconds
#    Time in inactive batches        = 1.0264e+00 seconds
#    Time in active batches          = 2.0249e+00 seconds
#    Time synchronizing fission bank = 1.0145e-01 seconds
#      Sampling source sites         = 7.8087e-02 seconds
#      SEND/RECV source sites        = 2.3043e-02 seconds
#    Time accumulating tallies       = 3.8957e-05 seconds
#    Time writing statepoints        = 7.7576e-03 seconds
#  Total time for finalization       = 9.5200e-07 seconds
#  Total time elapsed                = 8.5000e+00 seconds
#  Calculation Rate (inactive)       = 365366 particles/second
#  Calculation Rate (active)         = 370384 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.67607 +/- 0.00132
#  k-effective (Track-length)  = 0.67449 +/- 0.00146
#  k-effective (Absorption)    = 0.67889 +/- 0.00104
#  Combined k-effective        = 0.67829 +/- 0.00128
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
plt.errorbar(np.array(trisoPkFrac), np.array(k_eff_tPkFrac),np.array(kitPF))
# Out:
# <ErrorbarContainer object of 3 artists>
